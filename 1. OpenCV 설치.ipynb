# %% [markdown]
# # OpenCV

# %% [markdown]
# openCV(Open Source Computer Vision)은 오픈 소스 컴퓨터 비전 라이브러리 입니다.
# 객체, 얼굴, 행동 인식, 독순, 모션 추적 등의 응용 프로그램에서 사용합니다.
#
# python-OpenCvsharp 4.1.0.25를 사용합니다.

# %% [markdown]
# # OpenCV 설치

# %% [markdown]
# OpenCV 모듈은 pip를 통하여 설치할수 있습니다.
# 설치 명령어는 python -m pip install opencv-python 입니다.

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.1.0

# %% [markdown]
# # Python 플랫폼

# %% [markdown]
# ![image.png](attachment:image.png)
# 본 Python-OpenCV 예제는 위 이미지의 경로는 위와 같습니다.
# C:\Users\youdong\gitest01\python_ML\OpenCV\Image 폴더 안에 이미지 및 동영상을 저장
# 하여 사용합니다.

# %% [markdown]
# ![image.png](attachment:image.png)
# IDLE를 사용할 경우, 상대 경로를 이용하여 "Image/파일명" 으로 이미지를 불러올수 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)
# Visual Studio나 Jupyter Notebook을 사용할 경우, 절대 경로를 이용하여 "D:/Python/Image/파일명"으로 이미지를 불러올수 있습니다.
